# %%
from sqlalchemy import create_engine
from config import username, password
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import keras_tuner as kt
import tensorflow_addons as tfa

# %% [markdown]
# ## Data Preprocessing

# %%
engine = create_engine(f'postgresql://{username}:{password}@heart-disease.cdexedevamie.us-east-1.rds.amazonaws.com:5432/heart_disease_db')
connection = engine.connect()
data = pd.read_sql('select * from hearts', connection)
df = pd.DataFrame(data)

# Cleanup
# Age
bins = [0, 40, 50, 60, 70, 80]
# Create the names for the five bins
group_names = ["<40", "40-50", "50-60", "60-70", "70-80"]  
df["Age Range"] = pd.cut(df["age"], bins, labels=group_names, include_lowest=True)

#Trestbps   
bins = [0, 125, 150, 175, 200]
# Create the names for the five bins
group_names = ["<125", "125-150", "150-175", "175-200"]  
df["Trestbps Range"] = pd.cut(df["trestbps"], bins, labels=group_names, include_lowest=True)

#Chol  
bins = [0, 200, 300, 400, 500, 600]
# Create the names for the five bins
group_names = ["<200", "200-300", "300-400", "400-500", "500-600"]  
df["Chol Range"] = pd.cut(df["chol"], bins, labels=group_names, include_lowest=True)

#Thalach 
bins = [0, 100, 125, 150, 175, 300]
# Create the names for the five bins
group_names = ["<100", "100-125", "125-150", "150-175", "175-300"]  
df["Thalach Range"] = pd.cut(df["thalach"], bins, labels=group_names, include_lowest=True)

# Removing unnecessary columns age, trestbps, chol, and thalach
df.drop(['age', 'trestbps', 'chol', 'thalach'], axis='columns', inplace=True)
df_dummies = pd.get_dummies(df)
df_dummies.head()

# Splitting and Scaling
# Splitting into target (y) and features (X)
y = df_dummies['target'].values
X = df_dummies.drop(['target'], axis='columns')

# Splitting X and y into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# Scaling X sets with StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

# Transforming X_train and X_test
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Optimization

# %%
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Choice of activation functions
    activation = hp.Choice('activation', ['relu', 'tanh'])

    # Kerastuner decides number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1, max_value=10, step=2), activation=activation, input_shape=(X_train_scaled.shape[1], )))
    
    # Kerastuner decides number of additional hidden layers and neurons included
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i), 
            min_value=1, max_value=20, step=2), activation=activation))
    
    # Output layer
    nn_model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

    # Compile
    nn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

    return nn_model

# %%
# Setting up tuner
tuner = kt.Hyperband(create_model, objective='val_accuracy', max_epochs=20, hyperband_iterations=2)

# %%
# Running tuner to find combination with highest accuracy
tuner.search(X_train_scaled, y_train, epochs=20, validation_data=(X_test_scaled, y_test))
# Out:
# Trial 60 Complete [00h 00m 03s]
# val_accuracy: 0.9105058312416077
#
# Best val_accuracy So Far: 0.9533073902130127
# Total elapsed time: 00h 02m 13s
# INFO:tensorflow:Oracle triggered exit

# %%
# Getting best hyperparameters
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'relu',
#  'first_units': 9,
#  'num_layers': 5,
#  'units_0': 17,
#  'units_1': 9,
#  'units_2': 17,
#  'units_3': 9,
#  'units_4': 13,
#  'units_5': 5,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 0,
#  'tuner/bracket': 0,
#  'tuner/round': 0}

# %%
# Making a model with the best hyperparameters
nn = tuner.hypermodel.build(best_hyper)
nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6924 - accuracy: 0.5143
# Epoch 2/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6898 - accuracy: 0.6263
# Epoch 3/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6854 - accuracy: 0.6458
# Epoch 4/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6745 - accuracy: 0.6667
# Epoch 5/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6528 - accuracy: 0.6901
# Epoch 6/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6241 - accuracy: 0.7135
# Epoch 7/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5909 - accuracy: 0.7487
# Epoch 8/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5521 - accuracy: 0.7747
# Epoch 9/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4998 - accuracy: 0.7852
# Epoch 10/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4498 - accuracy: 0.8086
# Epoch 11/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4095 - accuracy: 0.8398
# Epoch 12/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3784 - accuracy: 0.8594
# Epoch 13/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3521 - accuracy: 0.8607
# Epoch 14/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3298 - accuracy: 0.8763
# Epoch 15/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3101 - accuracy: 0.8880
# Epoch 16/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2936 - accuracy: 0.8880
# Epoch 17/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2751 - accuracy: 0.8958
# Epoch 18/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2589 - accuracy: 0.9049
# Epoch 19/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2450 - accuracy: 0.9102
# Epoch 20/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2344 - accuracy: 0.9089
# Epoch 21/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2221 - accuracy: 0.9206
# Epoch 22/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2120 - accuracy: 0.9245
# Epoch 23/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2044 - accuracy: 0.9206
# Epoch 24/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1918 - accuracy: 0.9323
# Epoch 25/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1781 - accuracy: 0.9362
# Epoch 26/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1682 - accuracy: 0.9440
# Epoch 27/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1602 - accuracy: 0.9427
# Epoch 28/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1512 - accuracy: 0.9479
# Epoch 29/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1415 - accuracy: 0.9505
# Epoch 30/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1292 - accuracy: 0.9531
# Epoch 31/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1205 - accuracy: 0.9544
# Epoch 32/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1131 - accuracy: 0.9570
# Epoch 33/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1069 - accuracy: 0.9583
# Epoch 34/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1014 - accuracy: 0.9557
# Epoch 35/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0947 - accuracy: 0.9701
# Epoch 36/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0889 - accuracy: 0.9674
# Epoch 37/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0828 - accuracy: 0.9714
# Epoch 38/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0771 - accuracy: 0.9792
# Epoch 39/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0709 - accuracy: 0.9792
# Epoch 40/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0661 - accuracy: 0.9779
# Epoch 41/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0618 - accuracy: 0.9844
# Epoch 42/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0585 - accuracy: 0.9844
# Epoch 43/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0543 - accuracy: 0.9844
# Epoch 44/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0507 - accuracy: 0.9844
# Epoch 45/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0479 - accuracy: 0.9857
# Epoch 46/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0459 - accuracy: 0.9857
# Epoch 47/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0441 - accuracy: 0.9883
# Epoch 48/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0395 - accuracy: 0.9909
# Epoch 49/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0391 - accuracy: 0.9909
# Epoch 50/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0374 - accuracy: 0.9896
# Epoch 51/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0340 - accuracy: 0.9909
# Epoch 52/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0313 - accuracy: 0.9909
# Epoch 53/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0310 - accuracy: 0.9922
# Epoch 54/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0332 - accuracy: 0.9909
# Epoch 55/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0284 - accuracy: 0.9896
# Epoch 56/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0262 - accuracy: 0.9922
# Epoch 57/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0257 - accuracy: 0.9896
# Epoch 58/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0215 - accuracy: 0.9922
# Epoch 59/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0195 - accuracy: 0.9922
# Epoch 60/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0181 - accuracy: 0.9948
# Epoch 61/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 0.9922
# Epoch 62/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0161 - accuracy: 0.9948
# Epoch 63/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0154 - accuracy: 0.9948
# Epoch 64/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0153 - accuracy: 0.9948
# Epoch 65/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0142 - accuracy: 0.9948
# Epoch 66/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0137 - accuracy: 0.9948
# Epoch 67/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0136 - accuracy: 0.9948
# Epoch 68/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0127 - accuracy: 0.9948
# Epoch 69/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0123 - accuracy: 0.9948
# Epoch 70/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0125 - accuracy: 0.9948
# Epoch 71/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0122 - accuracy: 0.9948
# Epoch 72/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0111 - accuracy: 0.9948
# Epoch 73/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0110 - accuracy: 0.9948
# Epoch 74/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0103 - accuracy: 0.9961
# Epoch 75/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 0.9961
# Epoch 76/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 0.9922
# Epoch 77/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 0.9948
# Epoch 78/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 0.9961
# Epoch 79/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 0.9935
# Epoch 80/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 0.9961
# Epoch 81/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0090 - accuracy: 0.9948
# Epoch 82/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0085 - accuracy: 0.9961
# Epoch 83/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0086 - accuracy: 0.9948
# Epoch 84/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0091 - accuracy: 0.9961
# Epoch 85/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 0.9948
# Epoch 86/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0127 - accuracy: 0.9935
# Epoch 87/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0101 - accuracy: 0.9922
# Epoch 88/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0085 - accuracy: 0.9961
# Epoch 89/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0085 - accuracy: 0.9935
# Epoch 90/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0085 - accuracy: 0.9961
# Epoch 91/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0087 - accuracy: 0.9961
# Epoch 92/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0084 - accuracy: 0.9961
# Epoch 93/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 0.9948
# Epoch 94/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0085 - accuracy: 0.9948
# Epoch 95/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 0.9961
# Epoch 96/100
# 24/24 [==============================] - 0s 1000us/step - loss: 0.0079 - accuracy: 0.9961
# Epoch 97/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 0.9935
# Epoch 98/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0078 - accuracy: 0.9961
# Epoch 99/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0076 - accuracy: 0.9961
# Epoch 100/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0073 - accuracy: 0.9948

# %%
# Evaluating best model with test data

# Calculating R2
y_true = y_test.reshape(-1, 1)
y_pred = nn.predict(X_test_scaled)
metric = tfa.metrics.r_square.RSquare()
metric.update_state(y_true, y_pred)
result = metric.result()
# Calculating loss and accuracy
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=0)
print(f'Loss: {model_loss}, Accuracy: {model_accuracy}, R2: {result.numpy()}')
# Out:
# 9/9 [==============================] - 0s 1ms/step
# Loss: 0.004432981368154287, Accuracy: 1.0, R2: 0.9958808422088623

# %%
# Saving the best model to HDF5 file
nn.save('Resources/Model/OptimizedModel.h5')
